# %%
import nipy
from nibabel.testing import data_path
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pathlib

# %%
path = pathlib.Path('./Brats2021_0495/')
brain_sample = {}
for file in path.iterdir():
    sample = nib.load(file)
    brain_sample[file.name[:-7]] = sample.get_fdata()

# %%
def plot_brain_slices(sample):
    fig, ax = plt.subplots(nrows=40, ncols=4, figsize=(12, 130))
    for i in range(155):
        firstslice = sample[:, : , i]
        ax[int(i/4)][i%4].imshow(firstslice, cmap='gray')
        ax[int(i/4)][i%4].set_title(i)
    plt.show()

# %%
print(brain_sample.keys())
# Out:
# dict_keys(['BraTS2021_00495_flair', 'BraTS2021_00495_t1', 'BraTS2021_00495_t2', 'BraTS2021_00495_t1ce', 'BraTS2021_00495_seg'])

# %%
plot_brain_slices(brain_sample['BraTS2021_00495_flair'])

# %%
fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(15, 10))

ax[0].imshow(brain_sample['BraTS2021_00495_flair'][:, :, 100], cmap='gray')
ax[0].set_title('Flair')
ax[1].imshow(brain_sample['BraTS2021_00495_t1'][:, :, 100], cmap='gray')
ax[1].set_title('t1')
ax[2].imshow(brain_sample['BraTS2021_00495_seg'][:, :, 100], cmap='gray')
ax[2].set_title('seg')
ax[3].imshow(brain_sample['BraTS2021_00495_t1ce'][:, :, 100], cmap='gray')
ax[3].set_title('t1ce')
ax[4].imshow(brain_sample['BraTS2021_00495_t2'][:, :, 100], cmap='gray')
ax[4].set_title('t2')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(30, 10))

ax[0].imshow(brain_sample['BraTS2021_00495_flair'][:, : , 100], cmap='gray')
ax[1].imshow(brain_sample['BraTS2021_00495_flair'][:, : , 100].astype(np.int16), cmap='gray')
ax[2].imshow(brain_sample['BraTS2021_00495_flair'][:, : , 100].astype(np.int32), cmap='gray')
ax[3].imshow(brain_sample['BraTS2021_00495_flair'][:, : , 100].astype(np.float16), cmap='gray')

# %%
import pickle
with open('/mnt/e/mgr/datasets/brain/train_images/BraTS2021_00084/BraTS2021_00084_slices_dict.pickle', 'rb') as handle:
    unserialized_data = pickle.load(handle)

plt.imshow(unserialized_data['seg'], cmap='gray')
